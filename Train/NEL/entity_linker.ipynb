# %% [markdown]
# # Named Entity Linking (NEL) Pipeline
#
# This notebook implements a comprehensive Named Entity Linking system for the GutBrainIE dataset. The pipeline uses a two-stage approach to link predicted entities to their corresponding URIs:
#
# ## **Linking Strategy**
#
# 1. **Exact Matching**: Direct text span matching against manually annotated training data
# 2. **Similarity Matching**: Semantic similarity using PubMedBERT embeddings for entities without exact matches
#
# ## **Pipeline Workflow**
#
# 1. **Extract Training Knowledge**: Build entity-to-URI mappings from gold standard annotations
# 2. **Analyze Coverage**: Evaluate exact match coverage on predicted entities
# 3. **Semantic Similarity**: Use embedding-based similarity for missed entities
# 4. **Final Linking**: Combine exact and similarity matches to assign URIs
#
# ## **Output**
# - Linked entities with URI assignments and confidence sources
# - Statistics on exact matches, similarity matches, and unlinked entities
# - Final predictions in evaluation format
#
# ## **Requirements**
# - GPU recommended for similarity matching (txtai + PubMedBERT)
# - Pre-generated URI definitions from `generate_definitions.ipynb`

# %% [markdown]
# ## Step 1: Extract Entity-to-URI Mappings from Training Data
#
# Build exact matching dictionaries from manually annotated data (dev, train_platinum, train_gold sets). We create mappings from normalized text spans to their corresponding URIs.
#
# **Strategy**: For entities with identical text spans but different URIs, we'll use the first URI found (as noted, better handling could be implemented as future work).

# %% [markdown]
# ### Text Span to URI Mapping (Case-Insensitive)
#
# Extract all entity linkages from training data for exact matching. If a predicted entity's text span (lowercase) matches exactly with training data, we assign the corresponding URI.
#
# **Note**: Some text spans may have multiple URIs in the training data. In such cases, we use the first URI found.

# %%
import json

# Define paths to training annotation files  
# Here we are commenting out the dev set to avoid data leakage when running inference on the dev set
# When evaluating on the test set, uncomment this line to include the dev annotations in the knowledge base
#dev_annotations_path = '../../Annotations/Dev/json_format/dev.json'
train_gold_annotations_path = '../../Annotations/Train/gold_quality/json_format/train_gold.json'
train_silver_annotations_path = '../../Annotations/Train/silver_quality/json_format/train_silver.json'

training_annotation_files = [
    #dev_annotations_path, 
    train_gold_annotations_path,
    train_silver_annotations_path
]

# Build mapping from text spans to URIs (case-insensitive)
text_span_to_uris = {}

print("Processing training annotations to build text span -> URI mappings...")

for annotation_file_path in training_annotation_files:
    with open(annotation_file_path, 'r', encoding='utf-8') as input_file:
        annotation_data = json.load(input_file)

    # Process each document's entities
    for document_id, document_content in annotation_data.items():
        for entity in document_content['entities']:
            normalized_text_span = entity['text_span'].lower()
            entity_label = entity['label']
            entity_uri = entity['uri']
            
            # Initialize set for this text span if not exists
            if normalized_text_span not in text_span_to_uris:
                text_span_to_uris[normalized_text_span] = set()
            
            # Add URI to the set for this text span
            text_span_to_uris[normalized_text_span].add(entity_uri)

# Analyze text spans with multiple URIs
ambiguous_text_spans_count = 0
for text_span, uri_set in text_span_to_uris.items():
    if len(uri_set) > 1:
        print(f'Ambiguous text span: "{text_span}" has multiple URIs: {uri_set}')
        ambiguous_text_spans_count += 1

print(f'\n=== Text Span Analysis ===')
print(f'Total unique text spans: {len(text_span_to_uris)}')
print(f'Text spans with multiple URIs: {ambiguous_text_spans_count}')
# Out:
# Processing training annotations to build text span -> URI mappings...
# Ambiguous text span: "gut microbiome dysbiosis" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007'}
# Ambiguous text span: "gut microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/OHMI_0000002', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OHMI_0000016', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "elderly patients" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C16268'}
# Ambiguous text span: "nc" has multiple URIs: {'http://snomed.info/id/449888003', 'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous text span: "subjective cognitive decline" has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0850292', 'http://id.nlm.nih.gov/mesh/D060825'}
# Ambiguous text span: "scd" has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0850292', 'http://id.nlm.nih.gov/mesh/D060825'}
# Ambiguous text span: "amnestic mild cognitive impairment" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C215366'}
# Ambiguous text span: "amci" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C215366'}
# Ambiguous text span: "patients" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "short-chain fatty acid (scfa)-producing bacteria" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000182'}
# Ambiguous text span: "nc group" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous text span: "scfa-producing bacteria" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCBITaxon_2811711', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000182'}
# Ambiguous text span: "gut microbiota alterations" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28344', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous text span: "ad" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "cd" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/CHEBI_22977', 'http://purl.obolibrary.org/obo/NCIT_C2965'}
# Ambiguous text span: "gut" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://purl.obolibrary.org/obo/NCIT_C12736'}
# Ambiguous text span: "mycobiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000006', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "ms" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous text span: "fungal microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000006', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "gut mycobiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000006', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "individuals" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous text span: "ms patients" has multiple URIs: {'http://snomed.info/id/103309006', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous text span: "saccharomyces" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0013345', 'http://purl.obolibrary.org/obo/NCIT_C77167'}
# Ambiguous text span: "neurodegenerative conditions" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous text span: "bioactive compounds" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28269', 'http://purl.obolibrary.org/obo/NCIT_C54060'}
# Ambiguous text span: "neurodegeneration" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous text span: "reactive oxygen species" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C722', 'https://uts.nlm.nih.gov/uts/umls/concept/C1537052', 'http://purl.obolibrary.org/obo/NCIT_C1421'}
# Ambiguous text span: "ros" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1537052', 'http://purl.obolibrary.org/obo/NCIT_C121322', 'http://purl.obolibrary.org/obo/NCIT_C1421'}
# Ambiguous text span: "schisandra chinensis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_50507', 'http://purl.obolibrary.org/obo/NCIT_C180903'}
# Ambiguous text span: "microbiomics" has multiple URIs: {'http://id.nlm.nih.gov/mesh/68008828', 'http://purl.obolibrary.org/obo/NCIT_C19247'}
# Ambiguous text span: "metabolomics" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49019', 'http://purl.obolibrary.org/obo/NCIT_C210457'}
# Ambiguous text span: "microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://purl.obolibrary.org/obo/OHMI_0000002', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "ad rats" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14182', 'http://purl.obolibrary.org/obo/NCIT_C160998'}
# Ambiguous text span: "intestinal barrier" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49478', 'http://snomed.info/id/360972004', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000191', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://purl.obolibrary.org/obo/NCIT_C49240'}
# Ambiguous text span: "short-chain fatty acid" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_26666', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000182'}
# Ambiguous text span: "gut microbes" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "metabolites" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/CHEBI_82933'}
# Ambiguous text span: "gut microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000016', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "antibiotic treatment" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C258', 'http://purl.obolibrary.org/obo/NCIT_C15620'}
# Ambiguous text span: "anaerotruncus colihominis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_244127', 'http://purl.obolibrary.org/obo/NCBITaxon_169435'}
# Ambiguous text span: "mesenteric lymph nodes" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C77641', 'http://purl.obolibrary.org/obo/NCIT_C12745'}
# Ambiguous text span: "fep" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C78576', 'http://purl.obolibrary.org/obo/NCIT_C28179'}
# Ambiguous text span: "app" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C28537', 'http://purl.obolibrary.org/obo/OMIT_0025607', 'http://purl.obolibrary.org/obo/NCIT_C16285'}
# Ambiguous text span: "bace1" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C16554', 'http://purl.obolibrary.org/obo/NCIT_C112893', 'http://purl.obolibrary.org/obo/NCIT_C112895'}
# Ambiguous text span: "il-1β" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50928', 'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C20522'}
# Ambiguous text span: "il-6" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C24504', 'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/OMIT_0016485', 'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/CHEBI_52998'}
# Ambiguous text span: "tnf-α" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18368', 'http://purl.obolibrary.org/obo/NCIT_C20535', 'http://purl.obolibrary.org/obo/PR_P06804'}
# Ambiguous text span: "iba1" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0030168', 'https://uts.nlm.nih.gov/uts/umls/concept/C1412299'}
# Ambiguous text span: "mda" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C94711'}
# Ambiguous text span: "il-4" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28596', 'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/CHEBI_52998'}
# Ambiguous text span: "il-10" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28600', 'http://purl.obolibrary.org/obo/NCIT_C20512'}
# Ambiguous text span: "sod" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D013482', 'http://purl.obolibrary.org/obo/NCIT_C16554'}
# Ambiguous text span: "beclin-1" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/PR_000004719'}
# Ambiguous text span: "oxidative stress" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C35041', 'http://purl.obolibrary.org/obo/NCIT_C17741'}
# Ambiguous text span: "mr" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D057182', 'http://purl.obolibrary.org/obo/NCIT_C154555', 'http://purl.obolibrary.org/obo/NCIT_C16809'}
# Ambiguous text span: "ruminococcaceae ucg005" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_3068309', 'http://purl.obolibrary.org/obo/NCIT_C85961'}
# Ambiguous text span: "holdemania" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C86442', 'http://purl.obolibrary.org/obo/NCBITaxon_2'}
# Ambiguous text span: "reverse mr analysis" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D057182', 'http://purl.obolibrary.org/obo/NCIT_C16809'}
# Ambiguous text span: "autism spectrum disorders" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C88412', 'http://purl.obolibrary.org/obo/NCIT_C89330', 'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C97161'}
# Ambiguous text span: "aβ" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://id.nlm.nih.gov/mesh/C078592'}
# Ambiguous text span: "aβ plaques" has multiple URIs: {'http://purl.obolibrary.org/obo/BTO_0002774', 'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://purl.obolibrary.org/obo/MP_0003329'}
# Ambiguous text span: "app/ps1 mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://www.informatics.jax.org/allele/MGI:3524957'}
# Ambiguous text span: "tg mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://id.nlm.nih.gov/mesh/D055647', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous text span: "lactobacillus rhamnosus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C76352', 'http://purl.obolibrary.org/obo/NCIT_C93144', 'http://purl.obolibrary.org/obo/NCBITaxon_47715'}
# Ambiguous text span: "immunofluorescence" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C142337', 'http://id.nlm.nih.gov/mesh/D005455'}
# Ambiguous text span: "neuronal damage" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/TXPO_0000225', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088', 'http://purl.obolibrary.org/obo/NCIT_C50670'}
# Ambiguous text span: "cx3cr1" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26209', 'http://purl.obolibrary.org/obo/NCIT_C24326'}
# Ambiguous text span: "chronic inflammatory disorders" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93210', 'http://purl.obolibrary.org/obo/NCIT_C174450'}
# Ambiguous text span: "neurodegenerative diseases" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C89338'}
# Ambiguous text span: "treated mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous text span: "3xtg-ad mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous text span: "western blotting" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_37704', 'http://id.nlm.nih.gov/mesh/D015153'}
# Ambiguous text span: "ad mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous text span: "central nervous system" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12438', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000005'}
# Ambiguous text span: "16s rrna sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous text span: "fecal microbiota" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000001', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C14424'}
# Ambiguous text span: "β2-ar" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C18106'}
# Ambiguous text span: "chmp4b" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/PR_000005437'}
# Ambiguous text span: "cerebral cortex" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12443', 'http://purl.obolibrary.org/obo/NCIT_C154779'}
# Ambiguous text span: "early-onset ad" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195945', 'http://www.ebi.ac.uk/efo/EFO_0022957', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "late-onset ad" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195946', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "cd33" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C97244', 'http://purl.obolibrary.org/obo/NCIT_C97245'}
# Ambiguous text span: "eoad" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195945', 'http://www.ebi.ac.uk/efo/EFO_0022957', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "load" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195946', 'http://www.ebi.ac.uk/efo/EFO_1001870', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "impaired cognition" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous text span: "fecal samples" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C200884', 'http://purl.obolibrary.org/obo/NCIT_C189125', 'http://purl.obolibrary.org/obo/NCIT_C25662'}
# Ambiguous text span: "gut microbiota analysis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000187'}
# Ambiguous text span: "gsh-px" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16554', 'http://id.nlm.nih.gov/mesh/D005979'}
# Ambiguous text span: "monoglobus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1981510', 'http://purl.obolibrary.org/obo/NCBITaxon_2039302'}
# Ambiguous text span: "impaired cognitive function" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous text span: "elderly people" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C3826770', 'http://purl.obolibrary.org/obo/NCIT_C16268'}
# Ambiguous text span: "dysbiosis of the gut microbiota" has multiple URIs: {'http://snomed.info/id/1149492007', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous text span: "neurological diseases" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C26835', 'https://uts.nlm.nih.gov/uts/umls/concept/C4699656', 'http://id.nlm.nih.gov/mesh/D009461'}
# Ambiguous text span: "mci patients" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "mild cognitive impairment" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C215366'}
# Ambiguous text span: "mci" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C215366'}
# Ambiguous text span: "intestinal microbiome" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous text span: "subjects" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C70668', 'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C18241', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "16 s rrna sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous text span: "groups" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C71468', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous text span: "cognitive function" has multiple URIs: {'http://snomed.info/id/373930000', 'http://purl.obolibrary.org/obo/NCIT_C16446', 'http://snomed.info/id/311465003', 'http://purl.obolibrary.org/obo/NCIT_C103850'}
# Ambiguous text span: "older adults" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000328', 'https://uts.nlm.nih.gov/uts/umls/concept/C3826770', 'http://purl.obolibrary.org/obo/NCIT_C16268'}
# Ambiguous text span: "snps" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18279', 'http://purl.obolibrary.org/obo/NCIT_C17004'}
# Ambiguous text span: "healthy controls" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C94342', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous text span: "altered microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "immune-mediated diseases" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/NCIT_C131176'}
# Ambiguous text span: "experimental autoimmune encephalomyelitis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3006', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775', 'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/NCIT_C34580'}
# Ambiguous text span: "eae" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3006', 'http://purl.obolibrary.org/obo/NCIT_C34527', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775', 'http://purl.obolibrary.org/obo/NCIT_C34580', 'http://purl.obolibrary.org/obo/NCIT_C2889'}
# Ambiguous text span: "eae mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C3006'}
# Ambiguous text span: "histological analyses" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000192'}
# Ambiguous text span: "principal component analysis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49291', 'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://id.nlm.nih.gov/mesh/D015999', 'http://id.nlm.nih.gov/mesh/D000084142'}
# Ambiguous text span: "spouses" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "gut microbiota dysbiosis" has multiple URIs: {'http://snomed.info/id/1149492007', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous text span: "oral and gut microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "gsk3β" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/NCIT_C29877'}
# Ambiguous text span: "rectal swab" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C173641', 'http://purl.obolibrary.org/obo/NCIT_C200884'}
# Ambiguous text span: "bray-curtis" has multiple URIs: {'http://purl.obolibrary.org/obo/GO_0098774', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000175'}
# Ambiguous text span: "probiotic group" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092'}
# Ambiguous text span: "rats" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C160998', 'http://purl.obolibrary.org/obo/NCBITaxon_9989', 'http://id.nlm.nih.gov/mesh/D017207'}
# Ambiguous text span: "cortex" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12439', 'http://purl.obolibrary.org/obo/NCIT_C12443'}
# Ambiguous text span: "stool" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C189125', 'http://purl.obolibrary.org/obo/NCIT_C13234'}
# Ambiguous text span: "16s rdna sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763', 'https://uts.nlm.nih.gov/uts/umls/concept/C5848503'}
# Ambiguous text span: "ad group" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C71468', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous text span: "neurofibrillary tangles" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D016874', 'http://purl.obolibrary.org/obo/NCIT_C75652'}
# Ambiguous text span: "bacteroidetes" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCIT_C76203'}
# Ambiguous text span: "ad pathology" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C39737', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "sp" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C91705', 'http://purl.obolibrary.org/obo/NCIT_C847', 'http://purl.obolibrary.org/obo/NCIT_C62649'}
# Ambiguous text span: "p-tau" has multiple URIs: {'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/NCIT_C75652', 'http://snomed.info/id/412631008'}
# Ambiguous text span: "s1pr5" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C104784'}
# Ambiguous text span: "gc-ms" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D008401', 'http://purl.obolibrary.org/obo/NCIT_C18475'}
# Ambiguous text span: "gm" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "hippocampal neuronal damage" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1395088', 'http://id.nlm.nih.gov/mesh/D009461'}
# Ambiguous text span: "mediation analysis" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C3824847', 'http://id.nlm.nih.gov/mesh/D000081983'}
# Ambiguous text span: "gut microbiota-driven metabolic alterations" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28344', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous text span: "nervous system" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12438', 'http://purl.obolibrary.org/obo/NCIT_C12755'}
# Ambiguous text span: "gm alterations" has multiple URIs: {'http://snomed.info/id/1149492007', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous text span: "erysipelatoclostridium" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_3025755', 'http://id.nlm.nih.gov/mesh/D004888'}
# Ambiguous text span: "humans" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_9605', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "metabolic dysregulation" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3235', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000137', 'http://purl.obolibrary.org/obo/HP_0032245'}
# Ambiguous text span: "caspase-1" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20145', 'http://purl.obolibrary.org/obo/NCIT_C18045'}
# Ambiguous text span: "16s ribosomal rna gene amplicon sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'https://uts.nlm.nih.gov/uts/umls/concept/C5848503'}
# Ambiguous text span: "ketogenic diet" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C15222', 'http://id.nlm.nih.gov/mesh/D000072001', 'http://snomed.info/id/765060000'}
# Ambiguous text span: "male mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000005'}
# Ambiguous text span: "females" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C46110', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004'}
# Ambiguous text span: "anxiety-like behavior" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26696', 'http://www.ebi.ac.uk/efo/EFO_1001877'}
# Ambiguous text span: "tau" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26532', 'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/NCIT_C75652', 'http://snomed.info/id/412631008'}
# Ambiguous text span: "qpcr" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C51962', 'http://purl.obolibrary.org/obo/NCIT_C17003'}
# Ambiguous text span: "neurodegenerative disease" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C39737'}
# Ambiguous text span: "postbiotics" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000152'}
# Ambiguous text span: "cognitive dysfunctions" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C53526'}
# Ambiguous text span: "intestinal microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "serum il-1β" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C20522'}
# Ambiguous text span: "formate" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_37527', 'http://purl.obolibrary.org/obo/CHEBI_15740'}
# Ambiguous text span: "wgs" has multiple URIs: {'http://id.nlm.nih.gov/mesh/68017421', 'http://purl.obolibrary.org/obo/NCIT_C19646'}
# Ambiguous text span: "multi-omics analysis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://id.nlm.nih.gov/mesh/68008828', 'http://id.nlm.nih.gov/mesh/D000095028', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000044'}
# Ambiguous text span: "hd" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48284', 'http://purl.obolibrary.org/obo/NCIT_C82342'}
# Ambiguous text span: "bacteroidota" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous text span: "uroviricota" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCBITaxon_2731618'}
# Ambiguous text span: "actinobacteria" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D039903', 'http://purl.obolibrary.org/obo/NCBITaxon_2013654'}
# Ambiguous text span: "verrucomicrobia" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_747582', 'http://purl.obolibrary.org/obo/NCBITaxon_74201'}
# Ambiguous text span: "parabacteroides" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://id.nlm.nih.gov/mesh/2042320', 'http://purl.obolibrary.org/obo/NCBITaxon_375288'}
# Ambiguous text span: "butyricicoccus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_186801', 'http://purl.obolibrary.org/obo/NCBITaxon_580596', 'http://id.nlm.nih.gov/mesh/D045856'}
# Ambiguous text span: "coprococcus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_33042', 'http://purl.obolibrary.org/obo/NCBITaxon_1269'}
# Ambiguous text span: "galactose" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C68482'}
# Ambiguous text span: "simpson" has multiple URIs: {'http://purl.obolibrary.org/obo/PCO_0000063', 'http://purl.obolibrary.org/obo/NCIT_C128616'}
# Ambiguous text span: "gut dysbiosis" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007', 'http://purl.obolibrary.org/obo/NCIT_C162870'}
# Ambiguous text span: "gut bacteria" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089', 'http://purl.obolibrary.org/obo/NCBITaxon_188930', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "neurological disease" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://id.nlm.nih.gov/mesh/D009461'}
# Ambiguous text span: "autism spectrum disorder" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C88412', 'http://purl.obolibrary.org/obo/NCIT_C89330', 'http://purl.obolibrary.org/obo/NCIT_C26835', 'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C97161'}
# Ambiguous text span: "pediatric multiple sclerosis" has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0018784', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous text span: "children" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C42708', 'http://id.nlm.nih.gov/mesh/D002648'}
# Ambiguous text span: "methanogenic archaea" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61092', 'http://purl.obolibrary.org/obo/NCBITaxon_2172'}
# Ambiguous text span: "dimethyl fumarate" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_76004', 'http://purl.obolibrary.org/obo/CHEBI_29806'}
# Ambiguous text span: "chronic neuroinflammatory disease" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C174450', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775'}
# Ambiguous text span: "ms microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous text span: "16s rrna gene sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous text span: "multi-omics approach" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000044', 'http://id.nlm.nih.gov/mesh/D000095028'}
# Ambiguous text span: "metabolomic analysis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://www.ebi.ac.uk/efo/EFO_0000752', 'http://purl.obolibrary.org/obo/NCIT_C49019', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000110'}
# Ambiguous text span: "fecal metabolites" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/CHEBI_82933'}
# Ambiguous text span: "serum metabolites" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_85234', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous text span: "marinifilaceae" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1573805', 'http://purl.obolibrary.org/obo/NCBITaxon_2018663'}
# Ambiguous text span: "akkermansiaceae" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_239934', 'http://purl.obolibrary.org/obo/NCBITaxon_1647988'}
# Ambiguous text span: "cns autoimmunity" has multiple URIs: {'http://www.ebi.ac.uk/efo/EFO_1000870', 'http://purl.obolibrary.org/obo/OMIT_0016272', 'http://purl.obolibrary.org/obo/NCIT_C2889'}
# Ambiguous text span: "oral microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000015', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "persons" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous text span: "hc" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_100756', 'http://purl.obolibrary.org/obo/NCIT_C94342', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous text span: "glutamate" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C687', 'http://purl.obolibrary.org/obo/NCIT_C1115'}
# Ambiguous text span: "glu" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C1115', 'http://purl.obolibrary.org/obo/CHEBI_73493'}
# Ambiguous text span: "γ-aminobutyric acid" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_229980', 'http://purl.obolibrary.org/obo/CHEBI_16865'}
# Ambiguous text span: "gaba" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_16865', 'http://purl.obolibrary.org/obo/NCIT_C687'}
# Ambiguous text span: "da" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_188286', 'http://purl.obolibrary.org/obo/CHEBI_42111', 'http://purl.obolibrary.org/obo/CHEBI_18243'}
# Ambiguous text span: "ne" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_172425', 'http://purl.obolibrary.org/obo/CHEBI_90022'}
# Ambiguous text span: "neuropsychiatric disorders" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2893', 'http://purl.obolibrary.org/obo/NCIT_C96413', 'http://purl.obolibrary.org/obo/MONDO_0859292', 'https://uts.nlm.nih.gov/uts/umls/concept/C6013326'}
# Ambiguous text span: "depression" has multiple URIs: {'http://snomed.info/id/1153570009', 'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/OMIT_0005141'}
# Ambiguous text span: "stress-related disorders" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C0599909', 'http://purl.obolibrary.org/obo/NCIT_C35041'}
# Ambiguous text span: "male rats" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000005'}
# Ambiguous text span: "healthy adults" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://id.nlm.nih.gov/mesh/D000328'}
# Ambiguous text span: "microbial metabolites" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/CHEBI_82933'}
# Ambiguous text span: "healthy individuals" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous text span: "neurological disorders" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C26835', 'http://id.nlm.nih.gov/mesh/D009461'}
# Ambiguous text span: "pd" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'http://purl.obolibrary.org/obo/NCIT_C26845', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous text span: "il-8" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0016751', 'http://purl.obolibrary.org/obo/NCIT_C24507', 'http://purl.obolibrary.org/obo/CHEBI_52998'}
# Ambiguous text span: "ifn-γ" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20496', 'http://purl.obolibrary.org/obo/CHEBI_52999'}
# Ambiguous text span: "mcp-1" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20907', 'http://purl.obolibrary.org/obo/NCIT_C20482'}
# Ambiguous text span: "il-1ra" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C38920'}
# Ambiguous text span: "il-17" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28608', 'http://purl.obolibrary.org/obo/NCIT_C20464'}
# Ambiguous text span: "men" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D008571', 'http://purl.obolibrary.org/obo/NCIT_C14366'}
# Ambiguous text span: "pro-inflammatory cytokines" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50928', 'http://purl.obolibrary.org/obo/NCIT_C20464'}
# Ambiguous text span: "mptp" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_17963', 'http://purl.obolibrary.org/obo/CHEBI_233275'}
# Ambiguous text span: "adult mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004'}
# Ambiguous text span: "dat" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C113524', 'http://id.nlm.nih.gov/mesh/D013813'}
# Ambiguous text span: "tyrosine hydroxylase" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C127894', 'http://purl.obolibrary.org/obo/NCIT_C2155'}
# Ambiguous text span: "phosphorylated α-synuclein" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C90119', 'http://purl.obolibrary.org/obo/NCIT_C90101'}
# Ambiguous text span: "spinal cord" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C33969', 'http://purl.obolibrary.org/obo/NCIT_C12464'}
# Ambiguous text span: "motor symptoms" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116600', 'http://purl.obolibrary.org/obo/NCIT_C4876'}
# Ambiguous text span: "neurodegenerative disorders" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C39737'}
# Ambiguous text span: "alpha-synuclein" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C90119', 'http://purl.obolibrary.org/obo/CHEBI_15781'}
# Ambiguous text span: "antibiotic-treated mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604'}
# Ambiguous text span: "cognitive deficit" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous text span: "α-syn" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C464860', 'http://purl.obolibrary.org/obo/NCIT_C90119'}
# Ambiguous text span: "proteins" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/CHEBI_82131'}
# Ambiguous text span: "tg rats" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C160998'}
# Ambiguous text span: "pd pathology" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous text span: "microbiota alterations" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28344', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous text span: "neurological and psychiatric disorders" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C96413', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous text span: "central nervous system diseases" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12438', 'http://purl.obolibrary.org/obo/NCIT_C2934'}
# Ambiguous text span: "control mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous text span: "scfa" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_26666', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000182'}
# Ambiguous text span: "women" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D014930', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "enteric neurons" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12623', 'http://purl.obolibrary.org/obo/NCIT_C52709'}
# Ambiguous text span: "neuropsychiatric diseases" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0003283', 'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/MONDO_0859292'}
# Ambiguous text span: "ancom" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C19680', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000187'}
# Ambiguous text span: "bacteroidales" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCBITaxon_171549'}
# Ambiguous text span: "human gut microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "periphery" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25233', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000191', 'http://purl.obolibrary.org/obo/NCIT_C13018'}
# Ambiguous text span: "interleukin-6" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50940', 'http://purl.obolibrary.org/obo/OMIT_0016485', 'http://purl.obolibrary.org/obo/CHEBI_52998'}
# Ambiguous text span: "synaptic proteins" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20158', 'http://purl.obolibrary.org/obo/CHEBI_3254'}
# Ambiguous text span: "postsynaptic density protein 95" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C033652', 'http://purl.obolibrary.org/obo/NCIT_C29570'}
# Ambiguous text span: "protein aggregation" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C62344', 'http://id.nlm.nih.gov/mesh/D066263'}
# Ambiguous text span: "prevotella 9" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1486939', 'http://id.nlm.nih.gov/mesh/D018720'}
# Ambiguous text span: "medial prefrontal cortex" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C3853912', 'http://purl.obolibrary.org/obo/NCIT_C154779'}
# Ambiguous text span: "cognitive deficits" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C92196', 'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C37940'}
# Ambiguous text span: "chronic social defeat stress" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C121275', 'https://uts.nlm.nih.gov/uts/umls/concept/C1510527'}
# Ambiguous text span: "csds" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1510527', 'http://purl.obolibrary.org/obo/NCIT_C35041'}
# Ambiguous text span: "blood microbiome" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000124', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous text span: "inflammatory diseases" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93210', 'http://purl.obolibrary.org/obo/NCIT_C3137'}
# Ambiguous text span: "tight junction proteins" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028142', 'http://purl.obolibrary.org/obo/NCIT_C13333'}
# Ambiguous text span: "zo-1" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C114824', 'http://purl.obolibrary.org/obo/OMIT_0028159', 'http://purl.obolibrary.org/obo/OMIT_0028142', 'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/CHEBI_3254'}
# Ambiguous text span: "claudin-5" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D062507', 'http://purl.obolibrary.org/obo/OMIT_0026886'}
# Ambiguous text span: "wt mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C14424'}
# Ambiguous text span: "metabolome" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13325', 'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/NCIT_C210457'}
# Ambiguous text span: "oral and gut microbiotas" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "bacteroidetes phyla" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C76203', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous text span: "vitamins" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_27300', 'http://purl.obolibrary.org/obo/NCIT_C944'}
# Ambiguous text span: "mild and moderate ad" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26845', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "inflammatory state" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3137', 'https://uts.nlm.nih.gov/uts/umls/concept/C3276087'}
# Ambiguous text span: "increased intestinal permeability" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1404951', 'http://purl.obolibrary.org/obo/NCIT_C53526', 'https://uts.nlm.nih.gov/uts/umls/concept/C5578082'}
# Ambiguous text span: "leaky gut" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5578085', 'http://purl.obolibrary.org/obo/NCIT_C28193', 'https://uts.nlm.nih.gov/uts/umls/concept/C5578082', 'http://snomed.info/id/81120009', 'http://purl.obolibrary.org/obo/NCIT_C34082'}
# Ambiguous text span: "neurodegenerative changes" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous text span: "cognitive decline" has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0850292', 'http://purl.obolibrary.org/obo/NCIT_C92196', 'http://id.nlm.nih.gov/mesh/D060825', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous text span: "microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous text span: "permutational multivariate analysis of variance" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D015999', 'http://purl.obolibrary.org/obo/NCIT_C53241'}
# Ambiguous text span: "permanova" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D015999', 'http://purl.obolibrary.org/obo/NCIT_C53241'}
# Ambiguous text span: "chao1" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C19044', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000157'}
# Ambiguous text span: "acinetobacter" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1591090', 'http://purl.obolibrary.org/obo/NCBITaxon_469'}
# Ambiguous text span: "sprague-dawley rats" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017207', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "aβ1-42" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://id.nlm.nih.gov/mesh/C075222', 'http://purl.obolibrary.org/obo/CHEBI_64647'}
# ...
# Ambiguous text span: "aß" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://purl.obolibrary.org/obo/CHEBI_60425'}
# Ambiguous text span: "ahr" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18106', 'http://purl.obolibrary.org/obo/NCIT_C17273'}
# Ambiguous text span: "cluster of differentiation 11b" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_59132', 'http://purl.obolibrary.org/obo/NCIT_C17373'}
# Ambiguous text span: "microbiota composition" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "organic acids" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_37527', 'http://purl.obolibrary.org/obo/CHEBI_64709'}
# Ambiguous text span: "flies" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000085', 'http://purl.obolibrary.org/obo/NCBITaxon_381473'}
# Ambiguous text span: "lactiplantibacillus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1590', 'http://purl.obolibrary.org/obo/NCBITaxon_33958'}
# Ambiguous text span: "nitrogen" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C61863'}
# Ambiguous text span: "age-related pathologies" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C0851830', 'http://purl.obolibrary.org/obo/NCIT_C18189'}
# Ambiguous text span: "fatty liver disease" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C84444', 'http://purl.obolibrary.org/obo/MONDO_0004790'}
# Ambiguous text span: "pbc" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C27167', 'http://purl.obolibrary.org/obo/NCIT_C196862'}
# Ambiguous text span: "fecal metagenomics" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'https://uts.nlm.nih.gov/uts/umls/concept/C5906995'}
# Ambiguous text span: "lipid metabolism" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C40645', 'http://purl.obolibrary.org/obo/NCIT_C25739'}
# Ambiguous text span: "control participants" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C29867'}
# Ambiguous text span: "ruthenibacterium lactatiformans" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1550024', 'http://purl.obolibrary.org/obo/NCBITaxon_186801'}
# Ambiguous text span: "neutrophils" has multiple URIs: {'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/NCIT_C16612', 'http://purl.obolibrary.org/obo/OMIT_0010527'}
# Ambiguous text span: "nk46" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1678', 'http://purl.obolibrary.org/obo/NCIT_C86199'}
# Ambiguous text span: "c. butyricum" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D003013', 'http://purl.obolibrary.org/obo/NCIT_C86273'}
# Ambiguous text span: "histidine" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/NCIT_C29597'}
# Ambiguous text span: "ad-like pathology" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "behavioral testing" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186', 'http://purl.obolibrary.org/obo/NCBITaxon_457483'}
# Ambiguous text span: "bfubb" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_33078', 'http://purl.obolibrary.org/obo/CHEBI_36080'}
# Ambiguous text span: "senescence-accelerated mouse prone 8 (samp8) mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous text span: "h&e staining" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C23011', 'http://purl.obolibrary.org/obo/NCIT_C23010'}
# Ambiguous text span: "aged samp8 mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous text span: "colonic bacteria" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C3510360', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "nucleic acids" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/CHEBI_37527'}
# Ambiguous text span: "periodontal disease" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C63743', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous text span: "gut microbiome analysis" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000187'}
# Ambiguous text span: "candidatus arthromitus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_33078', 'http://purl.obolibrary.org/obo/NCBITaxon_2'}
# Ambiguous text span: "galt" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13049', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000198'}
# Ambiguous text span: "aβ<sub>42</sub>" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://purl.obolibrary.org/obo/CHEBI_64647'}
# Ambiguous text span: "enteric microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://id.nlm.nih.gov/mesh/D000069196'}
# Ambiguous text span: "leptotrichia" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCIT_C86014'}
# Ambiguous text span: "fecal bacteria" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "gut microbiome community" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000200'}
# Ambiguous text span: "ms twins" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous text span: "cells" has multiple URIs: {'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/NCIT_C12508'}
# Ambiguous text span: "americans" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16310', 'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous text span: "teer" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017097', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000062'}
# Ambiguous text span: "adonis test" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D015999', 'http://purl.obolibrary.org/obo/NCIT_C53241'}
# Ambiguous text span: "dopaminergic neuronal damage" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'http://purl.obolibrary.org/obo/HP_0002529'}
# Ambiguous text span: "chronic inflammatory diseases" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C174450', 'http://purl.obolibrary.org/obo/NCIT_C93210', 'http://purl.obolibrary.org/obo/NCIT_C3137'}
# Ambiguous text span: "evs" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000049', 'http://purl.obolibrary.org/obo/NCIT_C153165'}
# Ambiguous text span: "anti-gal" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C121503', 'http://purl.obolibrary.org/obo/NCIT_C16295'}
# Ambiguous text span: "hesperidin" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C70554', 'http://purl.obolibrary.org/obo/NCIT_C68460'}
# Ambiguous text span: "nobiletin" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_7602', 'http://purl.obolibrary.org/obo/NCIT_C70554'}
# Ambiguous text span: "experimental autoimmune encephalitis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3006', 'http://purl.obolibrary.org/obo/NCIT_C26760'}
# Ambiguous text span: "nmd" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C692', 'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/CHEBI_31882'}
# Ambiguous text span: "buried food test" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186', 'http://snomed.info/id/252249003'}
# Ambiguous text span: "pole descent test" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186', 'http://purl.obolibrary.org/obo/NCIT_C47891'}
# Ambiguous text span: "pyriform cortex" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D066195', 'http://purl.obolibrary.org/obo/NCIT_C12443'}
# Ambiguous text span: "pms" has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0018784', 'http://purl.obolibrary.org/obo/NCIT_C3243', 'https://uts.nlm.nih.gov/uts/umls/concept/C4699656'}
# Ambiguous text span: "indole-3-lactic acid" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_42111', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous text span: "metabolite-sensing gpcrs" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39001', 'http://purl.obolibrary.org/obo/NCIT_C18239'}
# Ambiguous text span: "gpr43" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18239', 'http://purl.obolibrary.org/obo/PR_000001583'}
# Ambiguous text span: "gpr41" has multiple URIs: {'http://purl.obolibrary.org/obo/PR_000001584', 'http://purl.obolibrary.org/obo/NCIT_C18239'}
# Ambiguous text span: "p-cresol" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous text span: "oral administration" has multiple URIs: {'http://purl.obolibrary.org/obo/OBI_0000952', 'http://snomed.info/id/394899003'}
# Ambiguous text span: "intestinal cells" has multiple URIs: {'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/NCIT_C49240'}
# Ambiguous text span: "campylobacterota" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_29547', 'http://id.nlm.nih.gov/mesh/D020560'}
# Ambiguous text span: "stool sample" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C200884', 'http://purl.obolibrary.org/obo/NCIT_C189125'}
# Ambiguous text span: "retinoic acid" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C68301', 'http://purl.obolibrary.org/obo/CHEBI_37527'}
# Ambiguous text span: "vitamin a" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_12777', 'http://purl.obolibrary.org/obo/NCIT_C944'}
# Ambiguous text span: "pyrosequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C99481', 'http://purl.obolibrary.org/obo/NCIT_C101293'}
# Ambiguous text span: "genetically predisposed individuals" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "commensals" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "fecal and oral microbiomes" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000015', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "muc2" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C115187', 'http://purl.obolibrary.org/obo/OMIT_0010119'}
# Ambiguous text span: "total cholesterol" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61032', 'http://purl.obolibrary.org/obo/CHEBI_16113'}
# Ambiguous text span: "psmd" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16342', 'http://purl.obolibrary.org/obo/OMIT_0024149'}
# Ambiguous text span: "depression-like behaviours" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/MP_0003360'}
# Ambiguous text span: "tryptophan metabolism" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25739', 'http://purl.obolibrary.org/obo/NCIT_C129885', 'http://purl.obolibrary.org/obo/CHEBI_27897', 'http://purl.obolibrary.org/obo/NCIT_C38875'}
# Ambiguous text span: "metabolomic profiles" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000110', 'http://purl.obolibrary.org/obo/NCIT_C210457'}
# Ambiguous text span: "y maze test" has multiple URIs: {'http://purl.obolibrary.org/obo/MMO_0000609', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000014'}
# Ambiguous text span: "neuronal senescence" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C17467', 'http://id.nlm.nih.gov/mesh/D016922'}
# Ambiguous text span: "central nervous system autoimmunity" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0016272', 'http://purl.obolibrary.org/obo/NCIT_C2934'}
# Ambiguous text span: "small intestine lymphoid tissues" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13049', 'http://purl.obolibrary.org/obo/NCIT_C12386'}
# Ambiguous text span: "zinc chloride" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C948', 'http://purl.obolibrary.org/obo/NCIT_C29865'}
# Ambiguous text span: "enterobacteriales" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C76310', 'http://purl.obolibrary.org/obo/NCBITaxon_91347'}
# Ambiguous text span: "3 × tg-ad mice" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous text span: "hd mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous text span: "pparα" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D047495', 'http://purl.obolibrary.org/obo/PR_000013056'}
# Ambiguous text span: "microbiota metabolites" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/CHEBI_82933'}
# Ambiguous text span: "li01" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C95186', 'http://purl.obolibrary.org/obo/NCBITaxon_2767887'}
# Ambiguous text span: "hplc" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16434', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000048'}
# Ambiguous text span: "kyna" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_18344', 'http://purl.obolibrary.org/obo/CHEBI_28683'}
# Ambiguous text span: "dnp" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_53289', 'http://purl.obolibrary.org/obo/NCIT_C26748'}
# Ambiguous text span: "microglia activation" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C64382', 'http://purl.obolibrary.org/obo/GO_0001774'}
# Ambiguous text span: "cns-directed autoimmunity" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0016272', 'http://purl.obolibrary.org/obo/NCIT_C2934'}
# Ambiguous text span: "p21" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C17783', 'http://purl.obolibrary.org/obo/CHEBI_36080'}
# Ambiguous text span: "svd" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C0262405', 'http://id.nlm.nih.gov/mesh/D059345'}
# Ambiguous text span: "human gut commensal" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089'}
# Ambiguous text span: "weighted gene co-expression network analysis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://edamontology.org/operation_3766'}
# Ambiguous text span: "rps3a" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0034986', 'http://purl.obolibrary.org/obo/NCIT_C16612'}
# Ambiguous text span: "rpl5" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C107652', 'http://purl.obolibrary.org/obo/NCIT_C16612'}
# Ambiguous text span: "viral-induced neurologic damage" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61555', 'http://purl.obolibrary.org/obo/NCIT_C50670'}
# Ambiguous text span: "axl" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18106', 'http://purl.obolibrary.org/obo/NCIT_C18359'}
# Ambiguous text span: "thc" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C459', 'http://snomed.info/id/72024007'}
# Ambiguous text span: "pip" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_22315', 'http://purl.obolibrary.org/obo/NCIT_C192634'}
# Ambiguous text span: "e. faecalis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C86368', 'http://id.nlm.nih.gov/mesh/D016983'}
#
# === Text Span Analysis ===
# Total unique text spans: 15006
# Text spans with multiple URIs: 1094

# %% [markdown]
# ### Text Span + Label to URI Mapping
#
# Create a more precise mapping that considers both text span AND entity label. This provides additional specificity for disambiguation when the same text can represent different entity types.

# %%
# Build mapping from (text_span, label) tuples to URIs
text_span_label_to_uris = {}

print("Building (text_span, label) -> URI mappings...")

for annotation_file_path in training_annotation_files:
    with open(annotation_file_path, 'r', encoding='utf-8') as input_file:
        annotation_data = json.load(input_file)

    # Process each document's entities
    for document_id, document_content in annotation_data.items():
        for entity in document_content['entities']:
            normalized_text_span = entity['text_span'].lower()
            entity_label = entity['label']
            entity_uri = entity['uri']
            
            # Create composite key from text span and label
            composite_key = (normalized_text_span, entity_label)
            
            # Initialize set for this composite key if not exists
            if composite_key not in text_span_label_to_uris:
                text_span_label_to_uris[composite_key] = set()
            
            # Add URI to the set for this composite key
            text_span_label_to_uris[composite_key].add(entity_uri)

# Analyze composite keys with multiple URIs
ambiguous_composite_keys_count = 0
for (text_span, label), uri_set in text_span_label_to_uris.items():
    if len(uri_set) > 1:
        print(f'Ambiguous: "{text_span}" (label: {label}) has multiple URIs: {uri_set}')
        ambiguous_composite_keys_count += 1

print(f'\n=== Text Span + Label Analysis ===')
print(f'Total unique (text_span, label) pairs: {len(text_span_label_to_uris)}')
print(f'Pairs with multiple URIs: {ambiguous_composite_keys_count}')
# Out:
# Building (text_span, label) -> URI mappings...
# Ambiguous: "gut microbiome dysbiosis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007'}
# Ambiguous: "gut microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/OHMI_0000002', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OHMI_0000016', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "elderly patients" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C16268'}
# Ambiguous: "subjective cognitive decline" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0850292', 'http://id.nlm.nih.gov/mesh/D060825'}
# Ambiguous: "scd" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0850292', 'http://id.nlm.nih.gov/mesh/D060825'}
# Ambiguous: "amnestic mild cognitive impairment" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C215366'}
# Ambiguous: "amci" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C215366'}
# Ambiguous: "patients" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "short-chain fatty acid (scfa)-producing bacteria" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000182'}
# Ambiguous: "nc group" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous: "scfa-producing bacteria" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCBITaxon_2811711', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000182'}
# Ambiguous: "gut microbiota alterations" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28344', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous: "gut" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://purl.obolibrary.org/obo/NCIT_C12736'}
# Ambiguous: "mycobiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000006', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "fungal microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000006', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "gut mycobiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000006', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "individuals" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous: "ms patients" (label: human) has multiple URIs: {'http://snomed.info/id/103309006', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous: "neurodegenerative conditions" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous: "bioactive compounds" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28269', 'http://purl.obolibrary.org/obo/NCIT_C54060'}
# Ambiguous: "neurodegeneration" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous: "reactive oxygen species" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C722', 'https://uts.nlm.nih.gov/uts/umls/concept/C1537052', 'http://purl.obolibrary.org/obo/NCIT_C1421'}
# Ambiguous: "ros" (label: chemical) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1537052', 'http://purl.obolibrary.org/obo/NCIT_C121322', 'http://purl.obolibrary.org/obo/NCIT_C1421'}
# Ambiguous: "microbiomics" (label: biomedical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/68008828', 'http://purl.obolibrary.org/obo/NCIT_C19247'}
# Ambiguous: "microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://purl.obolibrary.org/obo/OHMI_0000002', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "ad rats" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14182', 'http://purl.obolibrary.org/obo/NCIT_C160998'}
# Ambiguous: "intestinal barrier" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49478', 'http://snomed.info/id/360972004', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000191', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://purl.obolibrary.org/obo/NCIT_C49240'}
# Ambiguous: "gut microbes" (label: microbiome) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/CHEBI_82933'}
# Ambiguous: "gut microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000016', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "anaerotruncus colihominis" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_244127', 'http://purl.obolibrary.org/obo/NCBITaxon_169435'}
# Ambiguous: "mesenteric lymph nodes" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C77641', 'http://purl.obolibrary.org/obo/NCIT_C12745'}
# Ambiguous: "app" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C16285', 'http://purl.obolibrary.org/obo/OMIT_0025607'}
# Ambiguous: "bace1" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C16554', 'http://purl.obolibrary.org/obo/NCIT_C112895'}
# Ambiguous: "il-1β" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50928', 'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C20522'}
# Ambiguous: "il-6" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C24504', 'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/OMIT_0016485', 'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/CHEBI_52998'}
# Ambiguous: "tnf-α" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20535', 'http://purl.obolibrary.org/obo/PR_P06804'}
# Ambiguous: "iba1" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0030168', 'https://uts.nlm.nih.gov/uts/umls/concept/C1412299'}
# Ambiguous: "mda" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C94711'}
# Ambiguous: "il-4" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28596', 'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/CHEBI_52998'}
# Ambiguous: "il-10" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28600', 'http://purl.obolibrary.org/obo/NCIT_C20512'}
# Ambiguous: "sod" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D013482', 'http://purl.obolibrary.org/obo/NCIT_C16554'}
# Ambiguous: "beclin-1" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/PR_000004719'}
# Ambiguous: "oxidative stress" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C35041', 'http://purl.obolibrary.org/obo/NCIT_C17741'}
# Ambiguous: "mr" (label: statistical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D057182', 'http://purl.obolibrary.org/obo/NCIT_C16809'}
# Ambiguous: "ruminococcaceae ucg005" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_3068309', 'http://purl.obolibrary.org/obo/NCIT_C85961'}
# Ambiguous: "holdemania" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C86442', 'http://purl.obolibrary.org/obo/NCBITaxon_2'}
# Ambiguous: "reverse mr analysis" (label: statistical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D057182', 'http://purl.obolibrary.org/obo/NCIT_C16809'}
# Ambiguous: "autism spectrum disorders" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C88412', 'http://purl.obolibrary.org/obo/NCIT_C89330', 'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C97161'}
# Ambiguous: "aβ" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://id.nlm.nih.gov/mesh/C078592'}
# Ambiguous: "aβ plaques" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/BTO_0002774', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous: "app/ps1 mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://www.informatics.jax.org/allele/MGI:3524957'}
# Ambiguous: "tg mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://id.nlm.nih.gov/mesh/D055647', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous: "lactobacillus rhamnosus" (label: dietary supplement) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93144', 'http://purl.obolibrary.org/obo/NCBITaxon_47715'}
# Ambiguous: "immunofluorescence" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C142337', 'http://id.nlm.nih.gov/mesh/D005455'}
# Ambiguous: "neuronal damage" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/TXPO_0000225', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088', 'http://purl.obolibrary.org/obo/NCIT_C50670'}
# Ambiguous: "chronic inflammatory disorders" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93210', 'http://purl.obolibrary.org/obo/NCIT_C174450'}
# Ambiguous: "intestinal barrier" (label: microbiome) has multiple URIs: {'http://snomed.info/id/360972004', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous: "neurodegenerative diseases" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C89338'}
# Ambiguous: "treated mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous: "3xtg-ad mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous: "western blotting" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_37704', 'http://id.nlm.nih.gov/mesh/D015153'}
# Ambiguous: "ad mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous: "16s rrna sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "fecal microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C14424'}
# Ambiguous: "β2-ar" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C18106'}
# Ambiguous: "chmp4b" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/PR_000005437'}
# Ambiguous: "cerebral cortex" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12443', 'http://purl.obolibrary.org/obo/NCIT_C154779'}
# Ambiguous: "early-onset ad" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195945', 'http://www.ebi.ac.uk/efo/EFO_0022957', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "late-onset ad" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195946', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "cd33" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C97244', 'http://purl.obolibrary.org/obo/NCIT_C97245'}
# Ambiguous: "eoad" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195945', 'http://www.ebi.ac.uk/efo/EFO_0022957', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "load" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195946', 'http://www.ebi.ac.uk/efo/EFO_1001870', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "impaired cognition" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous: "gut microbiota analysis" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000187'}
# Ambiguous: "gsh-px" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16554', 'http://id.nlm.nih.gov/mesh/D005979'}
# Ambiguous: "monoglobus" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1981510', 'http://purl.obolibrary.org/obo/NCBITaxon_2039302'}
# Ambiguous: "impaired cognitive function" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous: "elderly people" (label: human) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C3826770', 'http://purl.obolibrary.org/obo/NCIT_C16268'}
# Ambiguous: "dysbiosis of the gut microbiota" (label: DDF) has multiple URIs: {'http://snomed.info/id/1149492007', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous: "neurological diseases" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C26835', 'https://uts.nlm.nih.gov/uts/umls/concept/C4699656', 'http://id.nlm.nih.gov/mesh/D009461'}
# Ambiguous: "mci patients" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "mild cognitive impairment" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C215366'}
# Ambiguous: "mci" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C215366'}
# Ambiguous: "intestinal microbiome" (label: microbiome) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous: "subjects" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C70668', 'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C18241', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "16 s rrna sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "groups" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous: "cognitive function" (label: DDF) has multiple URIs: {'http://snomed.info/id/373930000', 'http://purl.obolibrary.org/obo/NCIT_C16446', 'http://snomed.info/id/311465003', 'http://purl.obolibrary.org/obo/NCIT_C103850'}
# Ambiguous: "older adults" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000328', 'https://uts.nlm.nih.gov/uts/umls/concept/C3826770', 'http://purl.obolibrary.org/obo/NCIT_C16268'}
# Ambiguous: "cd" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C2965'}
# Ambiguous: "snps" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18279', 'http://purl.obolibrary.org/obo/NCIT_C17004'}
# Ambiguous: "healthy controls" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C94342', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous: "altered microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "immune-mediated diseases" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/NCIT_C131176'}
# Ambiguous: "experimental autoimmune encephalomyelitis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3006', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775', 'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/NCIT_C34580'}
# Ambiguous: "eae" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3006', 'http://purl.obolibrary.org/obo/NCIT_C34527', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775', 'http://purl.obolibrary.org/obo/NCIT_C34580', 'http://purl.obolibrary.org/obo/NCIT_C2889'}
# Ambiguous: "eae mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604'}
# Ambiguous: "histological analyses" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000192'}
# Ambiguous: "principal component analysis" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49291', 'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://id.nlm.nih.gov/mesh/D015999', 'http://id.nlm.nih.gov/mesh/D000084142'}
# Ambiguous: "spouses" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "gut microbiota dysbiosis" (label: DDF) has multiple URIs: {'http://snomed.info/id/1149492007', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous: "oral and gut microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "gsk3β" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/NCIT_C29877'}
# Ambiguous: "rectal swab" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C173641', 'http://purl.obolibrary.org/obo/NCIT_C200884'}
# Ambiguous: "bray-curtis" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/GO_0098774', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000175'}
# Ambiguous: "rats" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C160998', 'http://purl.obolibrary.org/obo/NCBITaxon_9989', 'http://id.nlm.nih.gov/mesh/D017207'}
# Ambiguous: "cortex" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12439', 'http://purl.obolibrary.org/obo/NCIT_C12443'}
# Ambiguous: "16s rdna sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763', 'https://uts.nlm.nih.gov/uts/umls/concept/C5848503'}
# Ambiguous: "ad group" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous: "bacteroidetes" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCIT_C76203'}
# Ambiguous: "ad pathology" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C39737', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "p-tau" (label: chemical) has multiple URIs: {'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/NCIT_C75652', 'http://snomed.info/id/412631008'}
# Ambiguous: "gc-ms" (label: biomedical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D008401', 'http://purl.obolibrary.org/obo/NCIT_C18475'}
# Ambiguous: "gm" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "hippocampal neuronal damage" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1395088', 'http://id.nlm.nih.gov/mesh/D009461'}
# Ambiguous: "gut microbiota-driven metabolic alterations" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28344', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous: "nervous system" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12438', 'http://purl.obolibrary.org/obo/NCIT_C12755'}
# Ambiguous: "gm alterations" (label: DDF) has multiple URIs: {'http://snomed.info/id/1149492007', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous: "erysipelatoclostridium" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_3025755', 'http://id.nlm.nih.gov/mesh/D004888'}
# Ambiguous: "humans" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_9605', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "metabolic dysregulation" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3235', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000137', 'http://purl.obolibrary.org/obo/HP_0032245'}
# Ambiguous: "caspase-1" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20145', 'http://purl.obolibrary.org/obo/NCIT_C18045'}
# Ambiguous: "16s ribosomal rna gene amplicon sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'https://uts.nlm.nih.gov/uts/umls/concept/C5848503'}
# Ambiguous: "male mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000005'}
# Ambiguous: "females" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C46110', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004'}
# Ambiguous: "anxiety-like behavior" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26696', 'http://www.ebi.ac.uk/efo/EFO_1001877'}
# Ambiguous: "tau" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26532', 'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/NCIT_C75652', 'http://snomed.info/id/412631008'}
# Ambiguous: "qpcr" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C51962', 'http://purl.obolibrary.org/obo/NCIT_C17003'}
# Ambiguous: "neurodegenerative disease" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C39737'}
# Ambiguous: "postbiotics" (label: dietary supplement) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000152'}
# Ambiguous: "cognitive dysfunctions" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C53526'}
# Ambiguous: "intestinal microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "serum il-1β" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C20522'}
# Ambiguous: "formate" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_37527', 'http://purl.obolibrary.org/obo/CHEBI_15740'}
# Ambiguous: "wgs" (label: biomedical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/68017421', 'http://purl.obolibrary.org/obo/NCIT_C19646'}
# Ambiguous: "multi-omics analysis" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://id.nlm.nih.gov/mesh/68008828', 'http://id.nlm.nih.gov/mesh/D000095028', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000044'}
# Ambiguous: "bacteroidota" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous: "uroviricota" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCBITaxon_2731618'}
# Ambiguous: "actinobacteria" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D039903', 'http://purl.obolibrary.org/obo/NCBITaxon_2013654'}
# Ambiguous: "verrucomicrobia" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_747582', 'http://purl.obolibrary.org/obo/NCBITaxon_74201'}
# Ambiguous: "parabacteroides" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://id.nlm.nih.gov/mesh/2042320', 'http://purl.obolibrary.org/obo/NCBITaxon_375288'}
# Ambiguous: "butyricicoccus" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_186801', 'http://purl.obolibrary.org/obo/NCBITaxon_580596', 'http://id.nlm.nih.gov/mesh/D045856'}
# Ambiguous: "coprococcus" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_33042', 'http://purl.obolibrary.org/obo/NCBITaxon_1269'}
# Ambiguous: "galactose" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C68482'}
# Ambiguous: "simpson" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/PCO_0000063', 'http://purl.obolibrary.org/obo/NCIT_C128616'}
# Ambiguous: "gut dysbiosis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007', 'http://purl.obolibrary.org/obo/NCIT_C162870'}
# Ambiguous: "gut bacteria" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089', 'http://purl.obolibrary.org/obo/NCBITaxon_188930', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://id.nlm.nih.gov/mesh/D000069196'}
# Ambiguous: "neurological disease" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://id.nlm.nih.gov/mesh/D009461'}
# Ambiguous: "autism spectrum disorder" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C88412', 'http://purl.obolibrary.org/obo/NCIT_C89330', 'http://purl.obolibrary.org/obo/NCIT_C26835', 'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C97161'}
# Ambiguous: "pediatric multiple sclerosis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0018784', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous: "children" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C42708', 'http://id.nlm.nih.gov/mesh/D002648'}
# Ambiguous: "methanogenic archaea" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61092', 'http://purl.obolibrary.org/obo/NCBITaxon_2172'}
# Ambiguous: "chronic neuroinflammatory disease" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C174450', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775'}
# Ambiguous: "ms microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous: "16s rrna gene sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "multi-omics approach" (label: biomedical technique) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000044', 'http://id.nlm.nih.gov/mesh/D000095028'}
# Ambiguous: "metabolomic analysis" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://www.ebi.ac.uk/efo/EFO_0000752', 'http://purl.obolibrary.org/obo/NCIT_C49019', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000110'}
# Ambiguous: "fecal metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/CHEBI_82933'}
# Ambiguous: "serum metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_85234', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous: "marinifilaceae" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1573805', 'http://purl.obolibrary.org/obo/NCBITaxon_2018663'}
# Ambiguous: "akkermansiaceae" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_239934', 'http://purl.obolibrary.org/obo/NCBITaxon_1647988'}
# Ambiguous: "cns autoimmunity" (label: DDF) has multiple URIs: {'http://www.ebi.ac.uk/efo/EFO_1000870', 'http://purl.obolibrary.org/obo/OMIT_0016272', 'http://purl.obolibrary.org/obo/NCIT_C2889'}
# Ambiguous: "oral microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000015', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "persons" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous: "hc" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C94342', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous: "glutamate" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C687', 'http://purl.obolibrary.org/obo/NCIT_C1115'}
# Ambiguous: "glu" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C1115', 'http://purl.obolibrary.org/obo/CHEBI_73493'}
# Ambiguous: "γ-aminobutyric acid" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_229980', 'http://purl.obolibrary.org/obo/CHEBI_16865'}
# Ambiguous: "gaba" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_16865', 'http://purl.obolibrary.org/obo/NCIT_C687'}
# Ambiguous: "da" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_188286', 'http://purl.obolibrary.org/obo/CHEBI_42111', 'http://purl.obolibrary.org/obo/CHEBI_18243'}
# Ambiguous: "ne" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_172425', 'http://purl.obolibrary.org/obo/CHEBI_90022'}
# Ambiguous: "neuropsychiatric disorders" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2893', 'http://purl.obolibrary.org/obo/NCIT_C96413', 'http://purl.obolibrary.org/obo/MONDO_0859292', 'https://uts.nlm.nih.gov/uts/umls/concept/C6013326'}
# Ambiguous: "depression" (label: DDF) has multiple URIs: {'http://snomed.info/id/1153570009', 'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/OMIT_0005141'}
# Ambiguous: "stress-related disorders" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C0599909', 'http://purl.obolibrary.org/obo/NCIT_C35041'}
# Ambiguous: "male rats" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000005'}
# Ambiguous: "healthy adults" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://id.nlm.nih.gov/mesh/D000328'}
# Ambiguous: "microbial metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/CHEBI_82933'}
# Ambiguous: "healthy individuals" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous: "neurological disorders" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C26835', 'http://id.nlm.nih.gov/mesh/D009461'}
# Ambiguous: "pd" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26845', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous: "tnf-α" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20535', 'http://purl.obolibrary.org/obo/NCIT_C18368'}
# Ambiguous: "il-6" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C24504', 'http://purl.obolibrary.org/obo/CHEBI_52998'}
# Ambiguous: "ifn-γ" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20496', 'http://purl.obolibrary.org/obo/CHEBI_52999'}
# Ambiguous: "il-1β" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50928', 'http://purl.obolibrary.org/obo/CHEBI_52998'}
# Ambiguous: "men" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D008571', 'http://purl.obolibrary.org/obo/NCIT_C14366'}
# Ambiguous: "pro-inflammatory cytokines" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50928', 'http://purl.obolibrary.org/obo/NCIT_C20464'}
# Ambiguous: "mptp" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_17963', 'http://purl.obolibrary.org/obo/CHEBI_233275'}
# Ambiguous: "adult mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004'}
# Ambiguous: "tyrosine hydroxylase" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C127894', 'http://purl.obolibrary.org/obo/NCIT_C2155'}
# Ambiguous: "phosphorylated α-synuclein" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C90119', 'http://purl.obolibrary.org/obo/NCIT_C90101'}
# Ambiguous: "spinal cord" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C33969', 'http://purl.obolibrary.org/obo/NCIT_C12464'}
# Ambiguous: "motor symptoms" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116600', 'http://purl.obolibrary.org/obo/NCIT_C4876'}
# Ambiguous: "neurodegenerative disorders" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C39737'}
# Ambiguous: "antibiotic-treated mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C94604'}
# Ambiguous: "cognitive deficit" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous: "α-syn" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/C464860', 'http://purl.obolibrary.org/obo/NCIT_C90119'}
# Ambiguous: "proteins" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/CHEBI_82131'}
# Ambiguous: "tg rats" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C160998'}
# Ambiguous: "pd pathology" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous: "microbiota alterations" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28344', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous: "neurological and psychiatric disorders" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C96413', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous: "central nervous system diseases" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12438', 'http://purl.obolibrary.org/obo/NCIT_C2934'}
# Ambiguous: "control mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous: "women" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D014930', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "neuropsychiatric diseases" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0003283', 'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/MONDO_0859292'}
# Ambiguous: "bacteroidales" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCBITaxon_171549'}
# Ambiguous: "human gut microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "periphery" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25233', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000191', 'http://purl.obolibrary.org/obo/NCIT_C13018'}
# Ambiguous: "synaptic proteins" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20158', 'http://purl.obolibrary.org/obo/CHEBI_3254'}
# Ambiguous: "postsynaptic density protein 95" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/C033652', 'http://purl.obolibrary.org/obo/NCIT_C29570'}
# Ambiguous: "protein aggregation" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C62344', 'http://id.nlm.nih.gov/mesh/D066263'}
# Ambiguous: "prevotella 9" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1486939', 'http://id.nlm.nih.gov/mesh/D018720'}
# Ambiguous: "medial prefrontal cortex" (label: anatomical location) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C3853912', 'http://purl.obolibrary.org/obo/NCIT_C154779'}
# Ambiguous: "cognitive deficits" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C92196', 'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C37940'}
# Ambiguous: "csds" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1510527', 'http://purl.obolibrary.org/obo/NCIT_C35041'}
# Ambiguous: "ketogenic diet" (label: food) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000072001', 'http://snomed.info/id/765060000'}
# Ambiguous: "blood microbiome" (label: microbiome) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000124', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous: "inflammatory diseases" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93210', 'http://purl.obolibrary.org/obo/NCIT_C3137'}
# Ambiguous: "tight junction proteins" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028142', 'http://purl.obolibrary.org/obo/NCIT_C13333'}
# Ambiguous: "wt mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C14424'}
# Ambiguous: "il-17" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28608', 'http://purl.obolibrary.org/obo/NCIT_C20464'}
# Ambiguous: "ifn-γ" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20496', 'http://purl.obolibrary.org/obo/CHEBI_52999'}
# Ambiguous: "metabolome" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13325', 'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/NCIT_C210457'}
# Ambiguous: "oral and gut microbiotas" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "bacteroidetes phyla" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C76203', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous: "mild and moderate ad" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26845', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "inflammatory state" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3137', 'https://uts.nlm.nih.gov/uts/umls/concept/C3276087'}
# Ambiguous: "increased intestinal permeability" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1404951', 'http://purl.obolibrary.org/obo/NCIT_C53526', 'https://uts.nlm.nih.gov/uts/umls/concept/C5578082'}
# Ambiguous: "leaky gut" (label: DDF) has multiple URIs: {'http://snomed.info/id/81120009', 'https://uts.nlm.nih.gov/uts/umls/concept/C5578085', 'http://purl.obolibrary.org/obo/NCIT_C28193', 'https://uts.nlm.nih.gov/uts/umls/concept/C5578082'}
# Ambiguous: "neurodegenerative changes" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous: "cognitive decline" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0850292', 'http://purl.obolibrary.org/obo/NCIT_C92196', 'http://id.nlm.nih.gov/mesh/D060825', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous: "microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous: "permutational multivariate analysis of variance" (label: statistical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D015999', 'http://purl.obolibrary.org/obo/NCIT_C53241'}
# Ambiguous: "permanova" (label: statistical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D015999', 'http://purl.obolibrary.org/obo/NCIT_C53241'}
# Ambiguous: "chao1" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C19044', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000157'}
# Ambiguous: "ad group" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C71468'}
# Ambiguous: "acinetobacter" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1591090', 'http://purl.obolibrary.org/obo/NCBITaxon_469'}
# Ambiguous: "sprague-dawley rats" (label: animal) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017207', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "app" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28537', 'http://purl.obolibrary.org/obo/NCIT_C16285'}
# Ambiguous: "aβ1-42" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://id.nlm.nih.gov/mesh/C075222', 'http://purl.obolibrary.org/obo/CHEBI_64647'}
# Ambiguous: "ci-ad" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "ci-nad" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "acetate" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_30089', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous: "cu" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "human microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous: "axonal damage" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1395088', 'http://purl.obolibrary.org/obo/NCIT_C50670'}
# Ambiguous: "vad" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C85220', 'http://purl.obolibrary.org/obo/NCIT_C34525'}
# Ambiguous: "aβ42" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://id.nlm.nih.gov/mesh/C075222', 'http://purl.obolibrary.org/obo/CHEBI_64647'}
# Ambiguous: "phosphorylated tau" (label: chemical) has multiple URIs: {'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/NCIT_C75652', 'http://snomed.info/id/412631008'}
# Ambiguous: "β-diversity" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C19044', 'http://purl.obolibrary.org/obo/OHMI_0000472'}
# Ambiguous: "picrust analysis" (label: biomedical technique) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C4761062', 'https://uts.nlm.nih.gov/uts/umls/concept/C5906995'}
# Ambiguous: "app/ps1 transgenic mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous: "pwms" (label: human) has multiple URIs: {'http://snomed.info/id/103309006', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "dmt" (label: biomedical technique) has multiple URIs: {'http://snomed.info/id/1340273002', 'http://purl.obolibrary.org/obo/NCIT_C170629'}
# Ambiguous: "beta diversity analyses" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000472', 'http://purl.obolibrary.org/obo/NCIT_C25391'}
# Ambiguous: "ms group" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous: "dmts" (label: biomedical technique) has multiple URIs: {'http://snomed.info/id/1340273002', 'http://purl.obolibrary.org/obo/NCIT_C170629'}
# Ambiguous: "vascular dementia" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C4786', 'http://purl.obolibrary.org/obo/NCIT_C34525'}
# Ambiguous: "interleukin-1 beta" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C20522'}
# Ambiguous: "memory impairment" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C78444', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous: "neurofibrillary tangles" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D016874', 'http://purl.obolibrary.org/obo/NCIT_C75652'}
# ...
# Ambiguous: "nasal microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous: "faecal samples" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/OBI_0002503', 'http://purl.obolibrary.org/obo/NCIT_C25662'}
# Ambiguous: "healthy control participants" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous: "atypical mdd group" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D011153', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "aß" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://purl.obolibrary.org/obo/CHEBI_60425'}
# Ambiguous: "ahr" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18106', 'http://purl.obolibrary.org/obo/NCIT_C17273'}
# Ambiguous: "cluster of differentiation 11b" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_59132', 'http://purl.obolibrary.org/obo/NCIT_C17373'}
# Ambiguous: "microbiota composition" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "altered gut microbiota composition" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous: "organic acids" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_37527', 'http://purl.obolibrary.org/obo/CHEBI_64709'}
# Ambiguous: "flies" (label: animal) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000085', 'http://purl.obolibrary.org/obo/NCBITaxon_381473'}
# Ambiguous: "lactiplantibacillus" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1590', 'http://purl.obolibrary.org/obo/NCBITaxon_33958'}
# Ambiguous: "nitrogen" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/NCIT_C61863'}
# Ambiguous: "age-related pathologies" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C0851830', 'http://purl.obolibrary.org/obo/NCIT_C18189'}
# Ambiguous: "fatty liver disease" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C84444', 'http://purl.obolibrary.org/obo/MONDO_0004790'}
# Ambiguous: "pbc" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C27167', 'http://purl.obolibrary.org/obo/NCIT_C196862'}
# Ambiguous: "fecal metagenomics" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'https://uts.nlm.nih.gov/uts/umls/concept/C5906995'}
# Ambiguous: "control participants" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C29867'}
# Ambiguous: "ruthenibacterium lactatiformans" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1550024', 'http://purl.obolibrary.org/obo/NCBITaxon_186801'}
# Ambiguous: "neutrophils" (label: anatomical location) has multiple URIs: {'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/OMIT_0010527'}
# Ambiguous: "nk46" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1678', 'http://purl.obolibrary.org/obo/NCIT_C86199'}
# Ambiguous: "c. butyricum" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D003013', 'http://purl.obolibrary.org/obo/NCIT_C86273'}
# Ambiguous: "histidine" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/NCIT_C29597'}
# Ambiguous: "stool" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C189125', 'http://purl.obolibrary.org/obo/NCIT_C13234'}
# Ambiguous: "ad-like pathology" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "amyloid plaques" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C95603', 'http://purl.obolibrary.org/obo/GO_0034205', 'http://purl.obolibrary.org/obo/NCIT_C54018'}
# Ambiguous: "behavioral testing" (label: biomedical technique) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186', 'http://purl.obolibrary.org/obo/NCBITaxon_457483'}
# Ambiguous: "bfubb" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_33078', 'http://purl.obolibrary.org/obo/CHEBI_36080'}
# Ambiguous: "senescence-accelerated mouse prone 8 (samp8) mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous: "h&e staining" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C23011', 'http://purl.obolibrary.org/obo/NCIT_C23010'}
# Ambiguous: "aged samp8 mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous: "nucleic acids" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/CHEBI_37527'}
# Ambiguous: "periodontal disease" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C63743', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous: "gut microbiome analysis" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000187'}
# Ambiguous: "candidatus arthromitus" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_33078', 'http://purl.obolibrary.org/obo/NCBITaxon_2'}
# Ambiguous: "galt" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13049', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000198'}
# Ambiguous: "aβ<sub>42</sub>" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64645', 'http://purl.obolibrary.org/obo/CHEBI_64647'}
# Ambiguous: "enteric microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://id.nlm.nih.gov/mesh/D000069196'}
# Ambiguous: "leptotrichia" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCIT_C86014'}
# Ambiguous: "fecal bacteria" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "gut microbiome community" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000200'}
# Ambiguous: "ms twins" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous: "cells" (label: anatomical location) has multiple URIs: {'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/NCIT_C12508'}
# Ambiguous: "americans" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16310', 'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://purl.obolibrary.org/obo/NCIT_C25190'}
# Ambiguous: "transepithelial electrical resistance" (label: biomedical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017097', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000062'}
# Ambiguous: "teer" (label: biomedical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017097', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000062'}
# Ambiguous: "adonis test" (label: statistical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D015999', 'http://purl.obolibrary.org/obo/NCIT_C53241'}
# Ambiguous: "alcohol" (label: food) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C86036', 'http://id.nlm.nih.gov/mesh/D000088082', 'http://purl.obolibrary.org/obo/NCIT_C2190'}
# Ambiguous: "dopaminergic neuronal damage" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'http://purl.obolibrary.org/obo/HP_0002529'}
# Ambiguous: "chronic inflammatory diseases" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C174450', 'http://purl.obolibrary.org/obo/NCIT_C93210', 'http://purl.obolibrary.org/obo/NCIT_C3137'}
# Ambiguous: "anti-gal" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C121503', 'http://purl.obolibrary.org/obo/NCIT_C16295'}
# Ambiguous: "ace" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C19044', 'http://purl.obolibrary.org/obo/NCIT_C19247'}
# Ambiguous: "experimental autoimmune encephalitis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3006', 'http://purl.obolibrary.org/obo/NCIT_C26760'}
# Ambiguous: "nmd" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/CHEBI_31882'}
# Ambiguous: "buried food test" (label: biomedical technique) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186', 'http://snomed.info/id/252249003'}
# Ambiguous: "pole descent test" (label: biomedical technique) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186', 'http://purl.obolibrary.org/obo/NCIT_C47891'}
# Ambiguous: "pyriform cortex" (label: anatomical location) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D066195', 'http://purl.obolibrary.org/obo/NCIT_C12443'}
# Ambiguous: "pms" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0018784', 'http://purl.obolibrary.org/obo/NCIT_C3243', 'https://uts.nlm.nih.gov/uts/umls/concept/C4699656'}
# Ambiguous: "indole-3-lactic acid" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_42111', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous: "metabolite-sensing gpcrs" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39001', 'http://purl.obolibrary.org/obo/NCIT_C18239'}
# Ambiguous: "p-cresol" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous: "intestinal cells" (label: anatomical location) has multiple URIs: {'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/NCIT_C49240'}
# Ambiguous: "campylobacterota" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_29547', 'http://id.nlm.nih.gov/mesh/D020560'}
# Ambiguous: "retinoic acid" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C68301', 'http://purl.obolibrary.org/obo/CHEBI_37527'}
# Ambiguous: "pyrosequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C99481', 'http://purl.obolibrary.org/obo/NCIT_C101293'}
# Ambiguous: "genetically predisposed individuals" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "fecal and oral microbiomes" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000015', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "muc2" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C115187', 'http://purl.obolibrary.org/obo/OMIT_0010119'}
# Ambiguous: "total cholesterol" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61032', 'http://purl.obolibrary.org/obo/CHEBI_16113'}
# Ambiguous: "psmd" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16342', 'http://purl.obolibrary.org/obo/OMIT_0024149'}
# Ambiguous: "depression-like behaviours" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/MP_0003360'}
# Ambiguous: "tryptophan metabolism" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C129885', 'http://purl.obolibrary.org/obo/CHEBI_27897'}
# Ambiguous: "y maze test" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/MMO_0000609', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000014'}
# Ambiguous: "neuronal senescence" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C17467', 'http://id.nlm.nih.gov/mesh/D016922'}
# Ambiguous: "central nervous system autoimmunity" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0016272', 'http://purl.obolibrary.org/obo/NCIT_C2934'}
# Ambiguous: "small intestine lymphoid tissues" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13049', 'http://purl.obolibrary.org/obo/NCIT_C12386'}
# Ambiguous: "zinc chloride" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C948', 'http://purl.obolibrary.org/obo/NCIT_C29865'}
# Ambiguous: "enterobacteriales" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C76310', 'http://purl.obolibrary.org/obo/NCBITaxon_91347'}
# Ambiguous: "3 × tg-ad mice" (label: animal) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous: "hd mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14240'}
# Ambiguous: "microbiota metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/CHEBI_82933'}
# Ambiguous: "hplc" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16434', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000048'}
# Ambiguous: "kyna" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_18344', 'http://purl.obolibrary.org/obo/CHEBI_28683'}
# Ambiguous: "microglia activation" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C64382', 'http://purl.obolibrary.org/obo/GO_0001774'}
# Ambiguous: "cns-directed autoimmunity" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0016272', 'http://purl.obolibrary.org/obo/NCIT_C2934'}
# Ambiguous: "p21" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C17783', 'http://purl.obolibrary.org/obo/CHEBI_36080'}
# Ambiguous: "svd" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C0262405', 'http://id.nlm.nih.gov/mesh/D059345'}
# Ambiguous: "human gut commensal" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089'}
# Ambiguous: "weighted gene co-expression network analysis" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://edamontology.org/operation_3766'}
# Ambiguous: "rps3a" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0034986', 'http://purl.obolibrary.org/obo/NCIT_C16612'}
# Ambiguous: "rpl5" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C107652', 'http://purl.obolibrary.org/obo/NCIT_C16612'}
# Ambiguous: "viral-induced neurologic damage" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61555', 'http://purl.obolibrary.org/obo/NCIT_C50670'}
# Ambiguous: "thc" (label: drug) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C459', 'http://snomed.info/id/72024007'}
# Ambiguous: "pip" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_22315', 'http://purl.obolibrary.org/obo/NCIT_C192634'}
# Ambiguous: "e. faecalis" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C86368', 'http://id.nlm.nih.gov/mesh/D016983'}
#
# === Text Span + Label Analysis ===
# Total unique (text_span, label) pairs: 15448
# Pairs with multiple URIs: 971

# %% [markdown]
# ## Step 2: Analyze Exact Match Coverage on Predictions
#
# Evaluate how many predicted entities can be linked using exact matches from our training data mappings. We test both text-only and text+label matching strategies.

# %% [markdown]
# ### Coverage Analysis: Text + Label Matching
#
# Test exact match coverage using the more precise (text_span, label) mapping approach.

# %%
# Load predicted entities for coverage analysis
predictions_file_path = '../../Predictions/NER/predicted_entities_dev_eval_format.json'
with open(predictions_file_path, 'r', encoding='utf-8') as input_file:
    predicted_entities_data = json.load(input_file)

# Analyze coverage using (text_span, label) matching
exact_matches_with_label = 0
missed_entities_with_label = 0
missed_entities_for_similarity = {}
missed_entity_index = 0

print("Analyzing exact match coverage with (text_span, label) approach...")

for document_id, document_content in predicted_entities_data.items():
    for predicted_entity in document_content['entities']:
        normalized_text_span = predicted_entity['text_span'].lower()
        entity_label = predicted_entity['label']
        composite_key = (normalized_text_span, entity_label)
        
        if composite_key in text_span_label_to_uris:
            exact_matches_with_label += 1
        else:
            missed_entities_with_label += 1
            # Store missed entity for similarity matching
            missed_entities_for_similarity[missed_entity_index] = (
                predicted_entity['text_span'], 
                entity_label
            )
            missed_entity_index += 1

print(f'\n=== Coverage Analysis (Text + Label) ===')
print(f'Exact matches: {exact_matches_with_label}')
print(f'Missed entities: {missed_entities_with_label}')
print(f'Coverage rate: {(exact_matches_with_label / (exact_matches_with_label + missed_entities_with_label) * 100):.1f}%')

# Save missed entities for similarity matching
MISSED_ENTITIES_FILE = 'missed_ents_text_and_label.json'
with open(MISSED_ENTITIES_FILE, 'w', encoding='utf-8') as output_file:
    json.dump(missed_entities_for_similarity, output_file, indent=4)

print(f'\nSaved {len(missed_entities_for_similarity)} missed entities to {MISSED_ENTITIES_FILE}')
# Out:
# Analyzing exact match coverage with (text_span, label) approach...
#
# === Coverage Analysis (Text + Label) ===
# Exact matches: 1237
# Missed entities: 1613
# Coverage rate: 43.4%
#
# Saved 1613 missed entities to missed_ents_text_and_label.json

# %% [markdown]
# ### Coverage Analysis: Text-Only Matching + Missed Entity Collection
#
# Test coverage using text-only matching (more permissive) and collect entities that cannot be matched for similarity-based linking.

# %%
# Analyze coverage using text-only matching and collect missed entities
exact_matches_text_only = 0
missed_entities_text_only = 0
missed_entities_for_similarity = {}
missed_entity_index = 0

print("Analyzing exact match coverage with text-only approach...")

for document_id, document_content in predicted_entities_data.items():
    for predicted_entity in document_content['entities']:
        normalized_text_span = predicted_entity['text_span'].lower()
        entity_label = predicted_entity['label']
        
        if normalized_text_span in text_span_to_uris:
            exact_matches_text_only += 1
        else:
            missed_entities_text_only += 1
            # Store missed entity for similarity matching
            missed_entities_for_similarity[missed_entity_index] = (
                predicted_entity['text_span'], 
                entity_label
            )
            missed_entity_index += 1

print(f'\n=== Coverage Analysis (Text Only) ===')
print(f'Exact matches: {exact_matches_text_only}')
print(f'Missed entities: {missed_entities_text_only}')
print(f'Coverage rate: {(exact_matches_text_only / (exact_matches_text_only + missed_entities_text_only) * 100):.1f}%')

# Save missed entities for similarity matching
MISSED_ENTITIES_FILE = 'missed_ents_text_only.json'
with open(MISSED_ENTITIES_FILE, 'w', encoding='utf-8') as output_file:
    json.dump(missed_entities_for_similarity, output_file, indent=4)

print(f'\nSaved {len(missed_entities_for_similarity)} missed entities to {MISSED_ENTITIES_FILE}')
# Out:
# Analyzing exact match coverage with text-only approach...
#
# === Coverage Analysis (Text Only) ===
# Exact matches: 1871
# Missed entities: 979
# Coverage rate: 65.6%
#
# Saved 979 missed entities to missed_ents_text_only.json

# %% [markdown]
# ## Step 3: Semantic Similarity Matching
#
# For entities that couldn't be matched exactly, use semantic similarity with PubMedBERT embeddings to find the most similar URI definitions from our knowledge base.
#
# **Process**:
# 1. Load pre-generated URI definitions
# 2. Build embedding index using txtai + PubMedBERT
# 3. Query missed entities against the definition corpus
# 4. Return top-10 most similar definitions for each missed entity

# %% [markdown]
# ### Build Embedding Index and Perform Similarity Search
#
# **GPU Recommended**: This step uses PubMedBERT embeddings which benefit significantly from GPU acceleration.

# %%
import txtai
from tqdm import tqdm
import os

print("Initializing PubMedBERT embeddings model...")
# Initialize txtai embeddings with PubMedBERT (biomedical domain-specific)
embeddings_model = txtai.Embeddings(path="neuml/pubmedbert-base-embeddings", content=True)

# Load URI definitions for embedding indexing
URI_DEFINITIONS_FILE = 'definitions/split_uri_definitions.json'
with open(URI_DEFINITIONS_FILE, 'r', encoding='utf-8') as input_file:
    uri_definitions_data = json.load(input_file)

print(f"Loaded {len(uri_definitions_data)} URI definitions")

if os.path.exists("embeddings_index"):
    print("Embeddings index already exists. Loading existing index...")
    embeddings_model.load("embeddings_index")
else:
    # Prepare data for indexing: (id, definition_text) tuples
    definitions_for_indexing = []
    for definition_id, definition_text in uri_definitions_data.items():
        definitions_for_indexing.append((definition_id, definition_text))

    print("Building embedding index... (this may take several minutes)")
    # Build the embedding index
    embeddings_model.index(definitions_for_indexing)

    # Save the index for future use
    print("Saving embedding index...")
    embeddings_model.save("embeddings_index") # Save in directory format
    embeddings_model.save("embeddings_index.tar.gz") # Also save as tar.gz for compatibility

# Load missed entities for similarity matching
MISSED_ENTITIES_FILE = 'missed_ents_text_only.json'
with open(MISSED_ENTITIES_FILE, 'r', encoding='utf-8') as input_file:
    missed_entities_data = json.load(input_file)

print(f"Performing similarity search for {len(missed_entities_data)} missed entities...")

# Perform similarity search for each missed entity
similarity_search_results = {}
for entity_id, (text_span, entity_label) in tqdm(missed_entities_data.items(), desc="Similarity matching"):
    # Search for top 10 most similar definitions
    search_results = embeddings_model.search(text_span, 10)
    
    similarity_search_results[entity_id] = {
        'text_span': text_span,
        'label': entity_label,
        'similarity_results': search_results
    }

# Save similarity results
SIMILARITY_RESULTS_FILE = 'similarity_matching_results.json'
with open(SIMILARITY_RESULTS_FILE, 'w', encoding='utf-8') as output_file:
    json.dump(similarity_search_results, output_file, ensure_ascii=False, indent=4)

print(f"Similarity matching completed. Results saved to {SIMILARITY_RESULTS_FILE}")

# %% [markdown]
# ## Step 4: Analyze Similarity Matching Results
#
# Process and analyze the similarity matching results to understand the quality and distribution of matches.

# %% [markdown]
# ### Data Format Conversion and Statistical Analysis
#
# Convert similarity results to different formats and analyze the distribution of similarity scores.

# %%
import json
import pickle

def convert_json_to_pickle(json_file_path, pickle_file_path):
    """Convert JSON file to pickle format for faster loading."""
    with open(json_file_path, 'r', encoding='utf-8') as input_file:
        data = json.load(input_file)
    
    with open(pickle_file_path, 'wb') as output_file:
        pickle.dump(data, output_file)
    
    print(f"Converted {json_file_path} to {pickle_file_path}")

def load_pickle_data(pickle_file_path):
    """Load data from pickle file."""
    with open(pickle_file_path, 'rb') as input_file:
        data = pickle.load(input_file)
    return data

# Convert similarity results to pickle format
SIMILARITY_RESULTS_JSON = 'similarity_matching_results.json'
SIMILARITY_RESULTS_PICKLE = 'similarity_matching_results.pkl'

convert_json_to_pickle(SIMILARITY_RESULTS_JSON, SIMILARITY_RESULTS_PICKLE)
similarity_results_dict = load_pickle_data(SIMILARITY_RESULTS_PICKLE)

# %%
from pprint import pprint

# Analyze similarity score distributions
total_similarity_score = 0
min_similarity_score = float('inf')
max_similarity_score = float('-inf')
total_entities_count = 0
all_top_scores = []

print("Analyzing similarity score distributions...")

# Collect top similarity scores for each entity
for entity_id, entity_data in similarity_results_dict.items():
    # Get the top similarity result (index 0)
    top_similarity_score = entity_data['similarity_results'][0]['score']
    
    # Update statistics
    total_similarity_score += top_similarity_score
    min_similarity_score = min(min_similarity_score, top_similarity_score)
    max_similarity_score = max(max_similarity_score, top_similarity_score)
    all_top_scores.append(top_similarity_score)
    total_entities_count += 1

# Sort scores for percentile analysis
all_top_scores.sort()

# Calculate average
average_similarity_score = total_similarity_score / total_entities_count if total_entities_count > 0 else 0

print(f"\n=== Similarity Score Analysis ===")
print(f"Total entities analyzed: {total_entities_count}")

# Show distribution of scores at different thresholds
print(f"\n=== Score Distribution Analysis ===")
for threshold_percent in range(10, 100, 10):
    threshold_value = threshold_percent / 100
    entities_below_threshold = sum(1 for score in all_top_scores if score < threshold_value)
    percentage_below = (entities_below_threshold / total_entities_count) * 100 if total_entities_count > 0 else 0
    
    print(f"Entities with similarity < {threshold_value:.2f}: {entities_below_threshold} ({percentage_below:.2f}%)")

print(f"\n=== Summary Statistics ===")
pprint({
    "average_similarity_score": round(average_similarity_score, 4),
    "min_similarity_score": round(min_similarity_score, 4),
    "max_similarity_score": round(max_similarity_score, 4),
    "median_score": round(all_top_scores[len(all_top_scores)//2], 4) if all_top_scores else 0
})

# %% [markdown]
# ### Process Similarity Results for Entity Linking
#
# Extract the top similarity match for each entity and prepare the mapping for final linking.

# %%
# Load similarity results
SIMILARITY_RESULTS_FILE = 'similarity_matching_results.json'
with open(SIMILARITY_RESULTS_FILE, 'r', encoding='utf-8') as input_file:
    similarity_results = json.load(input_file)

# Create mapping from text spans to top similarity match definition IDs
text_span_to_definition_id = {}

print("Processing similarity results to extract top matches...")

for entity_id, entity_data in similarity_results.items():
    entity_text_span = entity_data['text_span']
    top_similarity_result = entity_data['similarity_results'][0]  # Get top match
    top_definition_id = top_similarity_result['id']
    
    # Map text span to the ID of the most similar definition
    text_span_to_definition_id[entity_text_span] = top_definition_id

# Save processed similarity mappings
PROCESSED_SIMILARITY_FILE = "processed_similarity_res.json"
with open(PROCESSED_SIMILARITY_FILE, "w", encoding="utf-8") as output_file:
    json.dump(text_span_to_definition_id, output_file, indent=2)

print(f"Processed similarity mappings for {len(text_span_to_definition_id)} entities")
print(f"Saved to {PROCESSED_SIMILARITY_FILE}")

# %% [markdown]
# ## Step 5: Final Entity Linking
#
# Combine exact matching and similarity matching to assign URIs to all predicted entities. The linking priority is:
#
# 1. **Exact Match**: Direct text span match from training data
# 2. **Similarity Match**: Best semantic match from embedding search
# 3. **No Match**: Assign 'NA' if neither method finds a suitable URI
#
# Each entity will be tagged with its URI source for transparency.

# %% [markdown]
# ### Apply Linking Strategy to All Predicted Entities
#
# Execute the complete linking pipeline on all predicted entities and generate the final output with linking statistics.

# %%
# Initialize linking statistics counters
exact_match_text_label_count = 0
exact_match_text_only_count = 0
similarity_match_count = 0
no_match_count = 0

# Load processed similarity mappings
PROCESSED_SIMILARITY_FILE = 'processed_similarity_res.json'
with open(PROCESSED_SIMILARITY_FILE, 'r', encoding='utf-8') as input_file:
    text_span_to_similarity_definition_id = json.load(input_file)

# Load definition ID to URI mapping
DEFINITION_ID_TO_URI_FILE = "definitions/id_to_uri.json"
with open(DEFINITION_ID_TO_URI_FILE, "r", encoding="utf-8") as input_file:
    definition_id_to_uri = json.load(input_file)

print("Loading training data for exact matching...")

# Rebuild exact matching dictionaries (text span + label -> URI) and (text span -> URI) from training data
# Here we are commenting out the dev set to avoid data leakage when running inference on the dev set
# When evaluating on the test set, uncomment this line to include the dev annotations in the knowledge base
#dev_annotations_path = '../../Annotations/Dev/json_format/dev.json'
train_gold_annotations_path = '../../Annotations/Train/gold_quality/json_format/train_gold.json'
train_silver_annotations_path = '../../Annotations/Train/silver_quality/json_format/train_silver.json'

training_annotation_files = [
    #dev_annotations_path, 
    train_gold_annotations_path,
    train_silver_annotations_path
]

# Rebuild exact matching mappings for both strategies
exact_text_span_to_uris = {}
exact_text_span_label_to_uris = {}

for annotation_file_path in training_annotation_files:
    with open(annotation_file_path, 'r', encoding='utf-8') as input_file:
        annotation_data = json.load(input_file)

    for document_id, document_content in annotation_data.items():
        for entity in document_content['entities']:
            normalized_text_span = entity['text_span'].lower()
            entity_label = entity['label']
            entity_uri = entity['uri']
            
            # Build text-only mapping
            if normalized_text_span not in exact_text_span_to_uris:
                exact_text_span_to_uris[normalized_text_span] = set()
            exact_text_span_to_uris[normalized_text_span].add(entity_uri)
            
            # Build text+label mapping
            composite_key = (normalized_text_span, entity_label)
            if composite_key not in exact_text_span_label_to_uris:
                exact_text_span_label_to_uris[composite_key] = set()
            exact_text_span_label_to_uris[composite_key].add(entity_uri)

# Load predicted entities for final linking
predictions_file_path = '../../Predictions/NER/predicted_entities_dev_eval_format.json'
with open(predictions_file_path, "r", encoding="utf-8") as input_file:
    final_predictions = json.load(input_file)

print("Applying entity linking pipeline to all predicted entities...")

# Apply entity linking pipeline to each predicted entity
for document_id, document_content in final_predictions.items():
    for predicted_entity in document_content['entities']:
        entity_text_span = predicted_entity['text_span']
        normalized_text_span = entity_text_span.lower()
        entity_label = predicted_entity['label']
        composite_key = (normalized_text_span, entity_label)
        
        # Strategy 1: Try exact matching with text span + label first
        if composite_key in exact_text_span_label_to_uris:
            exact_match_text_label_count += 1
            # Use first URI from the set (as there could be multiple)
            assigned_uri = list(exact_text_span_label_to_uris[composite_key])[0]
            predicted_entity['uri'] = assigned_uri
            predicted_entity['uri_source'] = 'exact_match_text_label'
            
        # Strategy 2: Try exact matching with text span only
        elif normalized_text_span in exact_text_span_to_uris:
            exact_match_text_only_count += 1
            # Use first URI from the set (as there could be multiple)
            assigned_uri = list(exact_text_span_to_uris[normalized_text_span])[0]
            predicted_entity['uri'] = assigned_uri
            predicted_entity['uri_source'] = 'exact_match_text_only'
            
        # Strategy 3: Try similarity matching
        elif entity_text_span in text_span_to_similarity_definition_id:
            similarity_match_count += 1
            definition_id = text_span_to_similarity_definition_id[entity_text_span]
            assigned_uri = definition_id_to_uri[definition_id]
            predicted_entity['uri'] = assigned_uri
            predicted_entity['uri_source'] = 'similarity_match'
            
        # Strategy 4: No match found
        else:
            no_match_count += 1
            predicted_entity['uri'] = 'NA'
            predicted_entity['uri_source'] = 'no_match'

# Display final linking statistics
total_entities = exact_match_text_label_count + exact_match_text_only_count + similarity_match_count + no_match_count
print(f'\n=== Final Entity Linking Results ===')
print(f'Total entities processed: {total_entities}')
print(f'Exact matches (text + label): {exact_match_text_label_count} ({(exact_match_text_label_count/total_entities*100):.1f}%)')
print(f'Exact matches (text only): {exact_match_text_only_count} ({(exact_match_text_only_count/total_entities*100):.1f}%)')
print(f'Similarity matches: {similarity_match_count} ({(similarity_match_count/total_entities*100):.1f}%)')
print(f'No matches (NA): {no_match_count} ({(no_match_count/total_entities*100):.1f}%)')
print(f'Overall linking rate: {((exact_match_text_label_count + exact_match_text_only_count + similarity_match_count)/total_entities*100):.1f}%')

# Save final linked predictions
FINAL_PREDICTIONS_FILE = '../../Predictions/NEL/predicted_entities_dev.json'
with open(FINAL_PREDICTIONS_FILE, 'w', encoding='utf-8') as output_file:
    json.dump(final_predictions, output_file, indent=4)

print(f'\nFinal linked predictions saved to: {FINAL_PREDICTIONS_FILE}')
# Out:
# Loading training data for exact matching...
# Applying entity linking pipeline to all predicted entities...
#
# === Final Entity Linking Results ===
# Total entities processed: 2850
# Exact matches (text + label): 1237 (43.4%)
# Exact matches (text only): 634 (22.2%)
# Similarity matches: 979 (34.4%)
# No matches (NA): 0 (0.0%)
# Overall linking rate: 100.0%
#
# Final linked predictions saved to: ../../Predictions/NEL/predicted_entities_test.json
